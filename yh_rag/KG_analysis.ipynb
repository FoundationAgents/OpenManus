# %%
# %pip install --quiet pandas neo4j-rust-ext
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
GRAPHRAG_FOLDER = "output/20250912-180410/artifacts"

# %%
import time

import pandas as pd
from neo4j import GraphDatabase

# %%
NEO4J_URI = "neo4j://localhost"  # or neo4j+s://xxxx.databases.neo4j.io
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "password"  # your password
NEO4J_DATABASE = "neo4j"

# Create a Neo4j driver
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def batched_import(statement, df, batch_size=1000):
    """
    Import a dataframe into Neo4j using a batched approach.

    Parameters: statement is the Cypher query to execute, df is the dataframe to import, and batch_size is the number of rows to import in each batch.
    """
    total = len(df)
    start_s = time.time()
    for start in range(0, total, batch_size):
        batch = df.iloc[start : min(start + batch_size, total)]
        result = driver.execute_query(
            "UNWIND $rows AS value " + statement,
            rows=batch.to_dict("records"),
            database_=NEO4J_DATABASE,
        )
        print(result.summary.counters)
    print(f"{total} rows in {time.time() - start_s} s.")
    return total

# %%
# create constraints, idempotent operation

statements = [
    "\ncreate constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique",
    "\ncreate constraint document_id if not exists for (d:__Document__) require d.id is unique",
    "\ncreate constraint entity_id if not exists for (c:__Community__) require c.community is unique",
    "\ncreate constraint entity_id if not exists for (e:__Entity__) require e.id is unique",
    "\ncreate constraint entity_title if not exists for (e:__Entity__) require e.name is unique",
    "\ncreate constraint entity_title if not exists for (e:__Covariate__) require e.title is unique",
    "\ncreate constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique",
    "\n",
]

for statement in statements:
    if len((statement or "").strip()) > 0:
        print(statement)
        driver.execute_query(statement)
# Out:
# create constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique
#
# create constraint document_id if not exists for (d:__Document__) require d.id is unique
#
# create constraint entity_id if not exists for (c:__Community__) require c.community is unique
#
# create constraint entity_id if not exists for (e:__Entity__) require e.id is unique
#
# create constraint entity_title if not exists for (e:__Entity__) require e.name is unique
#
# create constraint entity_title if not exists for (e:__Covariate__) require e.title is unique
#
# create constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique

# %%
doc_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_documents.parquet", columns=["id", "title"]
)
doc_df.head(2)
# Out:
#                                                   id            title
# 0  8feea7195c789f4a8d3ec24ffcc358c9866b3874656277...  全国社保基金理事会-了解.md
# 1  94d225c1c8ae2dacd121dda777e3f003cc28f7a82da4d6...        价值投资入门.md

# %%
# Import documents
statement = """
MERGE (d:__Document__ {id:value.id})
SET d += value {.title}
"""

batched_import(statement, doc_df)
# Out:
# {'_contains_updates': True, 'labels_added': 7, 'nodes_created': 7, 'properties_set': 14}
# 7 rows in 0.5400161743164062 s.
# 7

# %%
text_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_text_units.parquet",
    columns=["id", "text", "n_tokens", "document_ids"],
)
text_df.head(2)
# Out:
#                                                   id    text  n_tokens  \
# 0  ca8fd26596b488b08f1eb2e65582d583a75132f2042c75...  三一重工研究         9
# 1  1d14e2e7e2dda35ec1b199fd8a13fb46730494874f232b...    平安研究         7
#
#                                         document_ids
# 0  [2b55193f0b6dd5706c7ae963d68d9865cb1872b3fa4da...
# 1  [7dddb724e6f9f0d0d010463fd108b1d53bc4ba2757f77...

# %%
statement = """
MERGE (c:__Chunk__ {id:value.id})
SET c += value {.text, .n_tokens}
WITH c, value
UNWIND value.document_ids AS document
MATCH (d:__Document__ {id:document})
MERGE (c)-[:PART_OF]->(d)
"""

batched_import(statement, text_df)
# Out:
# {'_contains_updates': True, 'labels_added': 14, 'relationships_created': 14, 'nodes_created': 14, 'properties_set': 42}
# 14 rows in 0.32142210006713867 s.
# 14

# %%
print(f"{GRAPHRAG_FOLDER}/create_final_entities.parquet")
# Out:
# output/20250912-180410/artifacts/create_final_entities.parquet

# %%
entity_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_entities.parquet",
    columns=[
        "title",
        "type",
        "description",
        "human_readable_id",
        "id",
        # "description_embedding",
        "text_unit_ids",
    ],
)
entity_df.head(40)
# Out:
#              title          type  \
# 0             三一重工  ORGANIZATION
# 1                无
# 2           三一重工研究
# 3             平安研究  ORGANIZATION
# 4             招商银行  ORGANIZATION
# 5               研究       CONCEPT
# 6      全国社会保障基金理事会  ORGANIZATION
# 7           国家社保基金       CONCEPT
# 8          社保基金理事会  ORGANIZATION
# 9          2000年4月         EVENT
# 10        基本养老保险基金       CONCEPT
# 11    城镇职工基本养老保险基金       CONCEPT
# 12  投资管理的战略方针和重大政策      STRATEGY
# 13          年度投资计划      STRATEGY
# 14          重大投资项目      STRATEGY
# 15          风险控制方案      STRATEGY
# 16          内部管理制度      STRATEGY
# 17             理事会  ORGANIZATION
# 18             理事长        PERSON
# 19            副理事长        PERSON
# 20             办公室  ORGANIZATION
# 21         外部投资管理人  ORGANIZATION
# 22        中央财政预算拨款       CONCEPT
# 23      中央部门上解的结余款       CONCEPT
# 24   未发放或暂缓支付的社保资金       CONCEPT
# 25            投资收益       CONCEPT
# 26            保值增值      STRATEGY
# 27           权益类投资       PRODUCT
# 28           固收类投资       PRODUCT
# 29            另类投资       PRODUCT
# 30            境外投资       PRODUCT
# 31             国务院  ORGANIZATION
# 32         全国人大财经委  ORGANIZATION
# 33            年度报告       PRODUCT
# 34          季度持仓概览       PRODUCT
# 35        重大投资事项公告       PRODUCT
# 36        十大流通股东明细       PRODUCT
# 37      2000 年 4 月         EVENT
# 38          养老金主账户       CONCEPT
# 39         决策和监管机构  ORGANIZATION
#
#                                           description  human_readable_id  \
# 0                                 三一重工是一家企业，文本围绕其开展研究                  0
# 1                                                                      1
# 2                                                                      2
# 3   平安研究是一个开展研究工作的组织，但文本未提供更多详细信息)<|COMPLETE|>("en...                  3
# 4                              一家开展银行业务的金融机构，进行相关研究工作                  4
# 5   招商银行开展的对各类事物进行探究、分析等活动）\n招商银行所进行的对金融相关或其他领域知识、...                  5
# 6   我国国家层面设立的、对国家社保基金进行决策和监督的最高机构，是国务院授权的事业性单位，直属财...                  6
# 7   即National Social Security Fund，是我国城镇职工基本养老保险基金...                  7
# 8   全国社会保障基金理事会的简称，承担着为我国基本养老保险体系提供长期稳定资金支持的重任，通过制...                  8
# 9                              全国社会保障基金理事会经国务院批准成立的时间                  9
# 10  我国重要的社会保障资金，国家社保基金为其提供长效支持\n我国重要的社会保障资金，国家社保基金...                 10
# 11  面向城镇职工的基本养老保险资金，国家社保基金为其提供长效支持，确保城镇职工退休后的养老保障\...                 11
# 12  全国社会保障基金理事会制定的关于社保基金投资管理的总体方向和重要政策，指导社保基金的投资方向...                 12
[0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 21  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 22  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 23  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 24  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 25  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 26  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 27  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 28  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 29  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 30  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 31  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 32  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 33  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 34  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 35  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 36  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 37  [0be002ba5024e23207dacf3a4c6c500821464ed3f9475...
# 38  [ddaf2b8262193a0a632d060bf3db50cf2df1aeb3f2afe...
# 39  [ddaf2b8262193a0a632d060bf3db50cf2df1aeb3f2afe...

# %%
# 修改后的Cypher查询语句
entity_statement = """
MERGE (e:__Entity__ {id:value.id})
SET e += value {.human_readable_id, name:replace(value.title,'"',''), .description}
WITH e, value
// 过滤 description_embedding 中的无效值
WITH e, value, [x IN coalesce(value.description_embedding, [0.1]) WHERE x IS NOT NULL AND x <> 'NaN' AND x <> 'Infinity' AND x <> '-Infinity'] AS valid_description_embedding
CALL db.create.setNodeVectorProperty(e, "description_embedding", valid_description_embedding)
CALL apoc.create.addLabels(e, case when coalesce(value.type,"") = "" then [] else [apoc.text.upperCamelCase(replace(value.type,'"',''))] end) yield node
UNWIND value.text_unit_ids AS text_unit
MATCH (c:__Chunk__ {id:text_unit})
MERGE (c)-[:HAS_ENTITY]->(e)
"""

batched_import(entity_statement, entity_df)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[15], line 15
#       1 # 修改后的Cypher查询语句
#       2 entity_statement = """
#       3 MERGE (e:__Entity__ {id:value.id})
#       4 SET e += value {.human_readable_id, name:replace(value.title,'"',''), .description}
#    (...)
#      12 MERGE (c)-[:HAS_ENTITY]->(e)
#      13 """
# ---> 15 batched_import(entity_statement, entity_df)
#
# Cell In[5], line 11, in batched_import(statement, df, batch_size)
#       9 for start in range(0, total, batch_size):
#      10     batch = df.iloc[start : min(start + batch_size, total)]
# ---> 11     result = driver.execute_query(
#      12         "UNWIND $rows AS value " + statement,
#      13         rows=batch.to_dict("records"),
#      14         database_=NEO4J_DATABASE,
#      15     )
#      16     print(result.summary.counters)
#      17 print(f"{total} rows in {time.time() - start_s} s.")
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:978, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     974     raise ValueError(
#     975         f"Invalid routing control value: {routing_!r}"
#     976     )
#     977 with session._pipelined_begin:
# --> 978     return session._run_transaction(
#     979         access_mode,
#     980         TelemetryAPI.DRIVER,
#     981         work,
#     982         (query_str, parameters, result_transformer_),
#     983         {},
#     984     )
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:588, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     586 tx = self._transaction
#     587 try:
# --> 588     result = transaction_function(tx, *args, **kwargs)
#     589 except asyncio.CancelledError:
#     590     # if cancellation callback has not been called yet:
#     591     if self._transaction is not None:
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:1314, in _work(tx, query, parameters, transformer)
#    1308 def _work(
#    1309     tx: ManagedTransaction,
#    1310     query: te.LiteralString,
#    1311     parameters: dict[str, t.Any],
#    1312     transformer: t.Callable[[Result], t.Union[_T]],
#    1313 ) -> _T:
# -> 1314     res = tx.run(query, parameters)
#    1315     return transformer(res)
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/work/transaction.py:206, in TransactionBase.run(self, query, parameters, **kwparameters)
#     203 self._results.append(result)
#     205 parameters = dict(parameters or {}, **kwparameters)
# --> 206 result._tx_ready_run(query, parameters)
#     208 return result
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/work/result.py:177, in Result._tx_ready_run(self, query, parameters)
#     173 def _tx_ready_run(self, query, parameters):
#     174     # BEGIN+RUN does not carry any extra on the RUN message.
#     175     # BEGIN {extra}
#     176     # RUN "query" {parameters} {extra}
# --> 177     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/work/result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/work/result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:193, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     191 def inner(*args, **kwargs):
#     192     try:
# --> 193         func(*args, **kwargs)
#     194     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     195         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:863, in Bolt.fetch_message(self)
#     859 # Receive exactly one message
#     860 tag, fields = self.inbox.pop(
#     861     hydration_hooks=self.responses[0].hydration_hooks
#     862 )
# --> 863 res = self._process_message(tag, fields)
#     864 self.idle_since = monotonic()
#     865 return res
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:263, in Response.on_failure(self, metadata)
#     261 handler = self.handlers.get("on_summary")
#     262 Util.callback(handler)
# --> 263 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `apoc.create.addLabels` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.}

# %%
rel_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_relationships.parquet",
    columns=[
        "source",
        "target",
        "id",
        # "rank",
        "weight",
        "human_readable_id",
        "description",
        "text_unit_ids",
    ],
)
rel_df.head(2)
# Out:
#   source  target                                    id  weight  \
# 0   三一重工  三一重工研究  87545acf-b20a-4a98-8d2c-d1dfa19cfeea     1.0
# 1      无       无  8cbd6b89-2c8d-471d-8fb1-a8186259398d     4.0
#
#    human_readable_id                                        description  \
# 0                  0                                   三一重工研究是针对三一重工进行的
# 1                  1  根据提供的描述，当前文本中未出现两个相关联的实体，也不存在明确提及的实体对或明显的实体关系。...
#
#                                        text_unit_ids
# 0  [ca8fd26596b488b08f1eb2e65582d583a75132f2042c7...
# 1  [ca8fd26596b488b08f1eb2e65582d583a75132f2042c7...

# %%
rel_statement = """
    MATCH (source:__Entity__ {name:replace(value.source,'"','')})
    MATCH (target:__Entity__ {name:replace(value.target,'"','')})
    // not necessary to merge on id as there is only one relationship per pair
    MERGE (source)-[rel:RELATED {id: value.id}]->(target)
    SET rel += value {.rank, .weight, .human_readable_id, .description, .text_unit_ids}
    RETURN count(*) as createdRels
"""

batched_import(rel_statement, rel_df)
# Out:
# {}
# 263 rows in 0.3031890392303467 s.
# 263

# %%
community_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_communities.parquet",
    columns=["id", "level", "title", "text_unit_ids", "relationship_ids"],
)

community_df.head(2)
# Out:
#                                      id  level        title  \
# 0  9bef19f5-87e1-426a-a8eb-6fcd93ff522a      0  Community 0
# 1  c345fc46-b2be-473b-810a-7233ee91df1e      0  Community 1
#
#                                        text_unit_ids  \
# 0  [5b66e700cc02ae197424a860eb9ca55055de332ba7fc5...
# 1  [9e469aa54fcfdbdfc7a9a6c0a34f72fee99ca77f00681...
#
#                                     relationship_ids
# 0  [171d0d53-4ff7-4fcc-b3e9-04219fa8e966, 17f0045...
# 1  [1557813a-7a61-44e8-9127-1f6276a155ee, 3d80cfe...

# %%
statement = """
MERGE (c:__Community__ {community:value.id})
SET c += value {.level, .title}
/*
UNWIND value.text_unit_ids as text_unit_id
MATCH (t:__Chunk__ {id:text_unit_id})
MERGE (c)-[:HAS_CHUNK]->(t)
WITH distinct c, value
*/
WITH *
UNWIND value.relationship_ids as rel_id
MATCH (start:__Entity__)-[:RELATED {id:rel_id}]->(end:__Entity__)
MERGE (start)-[:IN_COMMUNITY]->(c)
MERGE (end)-[:IN_COMMUNITY]->(c)
RETURn count(distinct c) as createdCommunities
"""

batched_import(statement, community_df)
# Out:
# {'_contains_updates': True, 'labels_added': 34, 'nodes_created': 34, 'properties_set': 102}
# 34 rows in 0.2894890308380127 s.
# 34

# %%
community_report_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_community_reports.parquet",
    columns=[
        "id",
        "community",
        "level",
        "title",
        "summary",
        "findings",
        "rank",
        "rank_explanation",
        "full_content",
    ],
)
community_report_df.head(2)
# Out:
#                                  id  community  level     title  \
# 0  52bb32121400439bbdf384c998bf89bc         11      1  公司节点变化社区
# 1  99f3c4970e22481ca34d0e7423d28fc2         12      1    价值投资社区
#
#                                              summary  \
# 0  该社区围绕公司节点变化展开，节点变化包含战略决策、人才储备、政府关系和领导人动向等要素，这些...
# 1  该社区围绕价值投资策略展开，涉及股票、企业内在价值等关键实体。价值投资以企业内在价值为决策依...
#
#                                             findings  rank  \
# 0  [{'explanation': '节点变化是该社区的核心实体，涵盖了公司发展过程中的关键变...   7.0
# 1  [{'explanation': '价值投资是该社区的核心策略，它基于企业内在价值进行投资决...   7.0
#
#                                  rank_explanation  \
# 0                  由于节点变化涉及公司发展的关键方面，其影响严重性评分为较高。
# 1  价值投资作为一种重要的投资策略，对金融市场和投资者决策有较大影响，因此影响严重性评分为较高。
#
#                                         full_content
# 0  # 公司节点变化社区\n\n该社区围绕公司节点变化展开，节点变化包含战略决策、人才储备、政府...
# 1  # 价值投资社区\n\n该社区围绕价值投资策略展开，涉及股票、企业内在价值等关键实体。价值投...

# %%
# Import communities
community_statement = """
MERGE (c:__Community__ {community:value.community})
SET c += value {.level, .title, .rank, .rank_explanation, .full_content, .summary}
WITH c, value
UNWIND range(0, size(value.findings)-1) AS finding_idx
WITH c, value, finding_idx, value.findings[finding_idx] as finding
MERGE (c)-[:HAS_FINDING]->(f:Finding {id:finding_idx})
SET f += finding
"""
batched_import(community_statement, community_report_df)
# Out:
# {'_contains_updates': True, 'labels_added': 210, 'relationships_created': 179, 'nodes_created': 210, 'properties_set': 754}
# 31 rows in 0.24725723266601562 s.
# 31

# %%
cov_df = (pd.read_parquet(f"{GRAPHRAG_FOLDER}/create_final_covariates.parquet"),)
#                         columns=["id","text_unit_id"])
cov_df.head(2)
# Subject id do not match entity ids
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 cov_df = (pd.read_parquet(f"{GRAPHRAG_FOLDER}/create_final_covariates.parquet"),)
#       2 #                         columns=["id","text_unit_id"])
#       3 cov_df.head(2)
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/pandas/io/parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)
#     270         **kwargs,
#     271     )
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/pandas/io/parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)
#     139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File ~/Desktop/git/OpenManus/venv/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/20250912-180410/artifacts/create_final_covariates.parquet'

# %%
# Import covariates
cov_statement = """
MERGE (c:__Covariate__ {id:value.id})
SET c += apoc.map.clean(value, ["text_unit_id", "document_ids", "n_tokens"], [NULL, ""])
WITH c, value
MATCH (ch:__Chunk__ {id: value.text_unit_id})
MERGE (ch)-[:HAS_COVARIATE]->(c)
"""
batched_import(cov_statement, cov_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       1 # Import covariates
#       2 cov_statement = """
#       3 MERGE (c:__Covariate__ {id:value.id})
#       4 SET c += apoc.map.clean(value, ["text_unit_id", "document_ids", "n_tokens"], [NULL, ""])
#    (...)
#       7 MERGE (ch)-[:HAS_COVARIATE]->(c)
#       8 """
# ----> 9 batched_import(cov_statement, cov_df)
#
# NameError: name 'cov_df' is not defined
