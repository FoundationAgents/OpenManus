# %%
# %pip install --quiet pandas neo4j-rust-ext
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
GRAPHRAG_FOLDER = "output/2025912-180410/artifacts"

# %%
import time

import pandas as pd
from neo4j import GraphDatabase

# %%
NEO4J_URI = "neo4j://localhost"  # or neo4j+s://xxxx.databases.neo4j.io
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "password"  # your password
NEO4J_DATABASE = "neo4j"

# Create a Neo4j driver
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def batched_import(statement, df, batch_size=1000):
    """
    Import a dataframe into Neo4j using a batched approach.

    Parameters: statement is the Cypher query to execute, df is the dataframe to import, and batch_size is the number of rows to import in each batch.
    """
    total = len(df)
    start_s = time.time()
    for start in range(0, total, batch_size):
        batch = df.iloc[start : min(start + batch_size, total)]
        result = driver.execute_query(
            "UNWIND $rows AS value " + statement,
            rows=batch.to_dict("records"),
            database_=NEO4J_DATABASE,
        )
        print(result.summary.counters)
    print(f"{total} rows in {time.time() - start_s} s.")
    return total

# %%
# create constraints, idempotent operation

statements = [
    "\ncreate constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique",
    "\ncreate constraint document_id if not exists for (d:__Document__) require d.id is unique",
    "\ncreate constraint entity_id if not exists for (c:__Community__) require c.community is unique",
    "\ncreate constraint entity_id if not exists for (e:__Entity__) require e.id is unique",
    "\ncreate constraint entity_title if not exists for (e:__Entity__) require e.name is unique",
    "\ncreate constraint entity_title if not exists for (e:__Covariate__) require e.title is unique",
    "\ncreate constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique",
    "\n",
]

for statement in statements:
    if len((statement or "").strip()) > 0:
        print(statement)
        driver.execute_query(statement)
# Out:
# create constraint chunk_id if not exists for (c:__Chunk__) require c.id is unique
#
# create constraint document_id if not exists for (d:__Document__) require d.id is unique
#
# create constraint entity_id if not exists for (c:__Community__) require c.community is unique
#
# create constraint entity_id if not exists for (e:__Entity__) require e.id is unique
#
# create constraint entity_title if not exists for (e:__Entity__) require e.name is unique
#
# create constraint entity_title if not exists for (e:__Covariate__) require e.title is unique
#
# create constraint related_id if not exists for ()-[rel:RELATED]->() require rel.id is unique

# %%
doc_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_documents.parquet", columns=["id", "title"]
)
doc_df.head(2)
# Out:
#                                                   id           title
# 0  6c29e796e48351f3cec2ca9014d88fd3c435586234cc97...  0313抓大鹅小游戏.csv
# 1  fe719e9837ef5872bbc9696bbfbadde65579efec13057a...      0329苹果.csv

# %%
# Import documents
statement = """
MERGE (d:__Document__ {id:value.id})
SET d += value {.title}
"""

batched_import(statement, doc_df)
# Out:
# {'_contains_updates': True, 'labels_added': 39, 'nodes_created': 39, 'properties_set': 78}
# 39 rows in 0.11804890632629395 s.
# 39

# %%
text_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_text_units.parquet",
    columns=["id", "text", "n_tokens", "document_ids"],
)
text_df.head(2)
# Out:
#                                                   id  \
# 0  759c5af2aad3e1985b6893b369a9b9781f045235d05d9f...
# 1  ffb7364bae253823e37dd9c595945797e21df3bc98d217...
#
#                                                 text  n_tokens  \
# 0  广告主id    cj8wd89bjr24\n产品名称\t我的亲家\n所属行业\t\n下单主...       265
# 1  广告主id    f8dfdh7w8nrby2o487\n产品名称\t农夫山泉\n所属行业\...       264
#
#                                         document_ids
# 0  [01584e6502dcd7e2e5743e63268e918edcf0dcc5d57bb...
# 1  [0363ee6502a3691e4a6218251c5ea5c1fe8b8c4ed2703...

# %%
statement = """
MERGE (c:__Chunk__ {id:value.id})
SET c += value {.text, .n_tokens}
WITH c, value
UNWIND value.document_ids AS document
MATCH (d:__Document__ {id:document})
MERGE (c)-[:PART_OF]->(d)
"""

batched_import(statement, text_df)
# Out:
# {'_contains_updates': True, 'labels_added': 42, 'relationships_created': 42, 'nodes_created': 42, 'properties_set': 126}
# 42 rows in 0.1136021614074707 s.
# 42

# %%
print(f"{GRAPHRAG_FOLDER}/create_final_entities.parquet")
# Out:
# output/20250109-110754/artifacts/create_final_entities.parquet

# %%
entity_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_entities.parquet",
    columns=[
        "title",
        "type",
        "description",
        "human_readable_id",
        "id",
        # "description_embedding",
        "text_unit_ids",
    ],
)
entity_df.head(40)
# Out:
#                  title    type  \
# 0         CJ8WD89BJR24   广告主ID
# 1                 我的亲家      产品
# 2                 相亲平台      行业
# 3                 真实可靠      特点
# 4            50岁以上老年人群      受众
# 5                   注册      诉求
# 6                  视频号      场景
# 7   F8DFDH7W8NRBY2O487   广告主ID
# 8                 农夫山泉      产品
# 9                 食品饮料      行业
# 10                 时评号  意向达人类型
# 11             关系比较好的号      特点
# 12                  舆论      特点
# 13                  辟谣      诉求
# 14         ZXCNU80BN2P   广告主ID
# 15               腾讯自选股      产品
# 16             金融-证券服务      行业
# 17       微信里贴身的证券服务小管家      特点
# 18        20-35岁的较年轻人群      受众
# 19             本科或以上学历      受众
# 20             一二线发达城市      受众
# 21       大学毕业生/职场新人/白领      受众
# 22        学习投资知识领微信立减金      诉求
# 23       教育培训（考研/考公为主）  意向达人类型
# 24                情感生活  意向达人类型
# 25                职场管理  意向达人类型
# 26            动漫二次元/游戏  意向达人类型
# 27        投资知识（入门/新手向）  意向达人类型
# 28        FJV8R4902NUV   广告主ID
# 29         《斗破苍穹·巅峰对决》      产品
# 30                  游戏      行业
# 31          斗破IP动漫粉丝人群      受众
# 32                游戏垂类      受众
# 33            斗破相关动漫账号  意向达人类型
# 34               泛动漫账号  意向达人类型
# 35    过往投放过游戏行业效果不错的账号  意向达人类型
# 36     精准触达粉丝人群,实现人群破圈      诉求
# 37                代理下单      场景
# 38                6月7日      场景
# 39                7月7日      场景
#
#                                           description  human_readable_id  \
# 0                                           广告主的唯一标识符                  0
# 1                                   我的亲家是一个家长帮子女相亲的平台                  1
# 2                               我的亲家所属的行业"\n我的亲家所属的行业                  2
# 3                               我的亲家是一个真实可靠的家长帮子女相亲平台                  3
# 4                                 我的亲家的目标人群是50岁以上老年人群                  4
# 5                                    我的亲家的推广诉求是增加注册用户                  5
# 6   视频号作为一个广告投放平台，被多个广告主选作其广告投放的场景。具体而言，《斗破苍穹·巅峰对决...                  6
# 7                                           广告主的唯一标识符                  7
# 8                                       农夫山泉是一款食品饮料产品                  8
# 9                                           农夫山泉所属的行业                  9
# 10        客户希望找的靠谱的号，用于辟谣和避免炒作\n客户希望找的靠谱的号，用于辟谣和避免炒作"                 10
# 11        客户希望找的关系比较好且可控度比较高的号\n客户希望找的关系比较好且可控度比较高的号"                 11
# 12                               农夫山泉最近面临的一些负面舆论，需要辟谣                 12
# 13                            农夫山泉希望通过合作达人的方式来进行舆论的辟谣                 13
# 14                                          广告主的唯一标识符                 14
# 15                         腾讯自选股是一款轻便、简洁、专业的股票分析和交易平台                 15
# 16                                         腾讯自选股所属的行业                 16
# 17                   腾讯自选股是微信里贴身的证券服务小管家，可以帮助用户实现轻松盯盘                 17
# 18                         年龄在20-35岁的较年轻人群是腾讯自选股的目标人群                 18
# 19                              本科或以上学历的人群是腾讯自选股的目标人群                 19
# 20                              一二线发达城市的人群是腾讯自选股的目标人群                 20
# 21                           大学毕业生/职场新人/白领是腾讯自选股的目标人群                 21
# 22             腾讯自选股的项目背景是以转化开户为目标，主推“学习投资知识领微信立减金”活动                 22
# 23                          优先考虑的达人类型包括教育培训（考研/考公为主）"                 23
# 24                                   优先考虑的达人类型包括情感生活"                 24
# 25                                   优先考虑的达人类型包括职场管理"                 25
# 26                               优先考虑的达人类型包括动漫二次元/游戏"                 26
# 27                           优先考虑的达人类型包括投资知识（入门/新手向）"                 27
# 28                                          广告主的唯一标识符                 28
# 29                                 《斗破苍穹·巅峰对决》是一款游戏产品                 29
# 30                  《斗破苍穹·巅峰对决》和《地下城与勇士：起源》均属于网络游戏行业。                 30
# 31                                 《斗破苍穹·巅峰对决》的目标人群之一                 31
# 32                                 《斗破苍穹·巅峰对决》的目标人群之一                 32
# 33                                 斗破相关动漫账号是潜在的意向达人类型                 33
# 34                                    泛动漫账号是潜在的意向达人类型                 34
# 35                        过往投放过游戏行业效果不错的账号是潜在的意向达人类型"                 35
# 36                   《斗破苍穹·巅峰对决》的推广诉求是精准触达粉丝人群,实现人群破圈                 36
# 37  《斗破苍穹·巅峰对决》的下单主体是代理，这种操作是由代理进行的，同时广告主也可以选择通过代理...                 37
# 38                            《斗破苍穹·巅峰对决》第一波投放时间是6月7日                 38
# 39                            《斗破苍穹·巅峰对决》第二波投放时间是7月7日                 39
#
#                                       id  \
# 0   ea06f8f1-4e57-42ab-9be8-0460235f055a
# 1   8f1aa682-6ad1-4b2f-8d21-756dbca89d37
# 2   4791dea7-c2f7-4c27-b7e4-cedfe7e5d6dc
# 3   7b075ae9-4766-46b7-9088-bd57b5465761
# 4   c526b9cf-a0cc-4e1c-b07d-80f082b7f4cb
# 5   9b81b812-99be-47d5-9dcb-c6077239d861
# 6   4b85d5c0-8574-48aa-a7d6-cb9893d7587d
# 7   c2dd0961-e61f-49e1-a9ea-3008a3273797
# 8   463d06f1-08ba-43f2-89a0-6633564b658a
# 9   77090906-9e7c-4ca9-abe7-5cb04caa92d5
# 10  f84eff0f-e9c0-4ed9-8ae8-2478485b53b3
# 11  15367b37-8307-4d14-afb4-8f992ed5367e
# 12  41acb2c5-919f-433c-ad31-6874be4e089c
# 13  1a2af7db-00a9-4aaf-b65c-3181ee53fdac
# 14  b7328d43-d1d9-41e9-ab6a-5ad5b4ffcc4d
# 15  34250038-1ce4-404b-a1d8-107953a5bc45
# 16  83d52923-c02a-44cc-aa2b-7de39856cd49
# 17  f3dfec43-3aa5-4736-8508-ebf721714f8e
# 18  10068aae-f93a-48d8-ae08-69fb13c4753f
# 19  4def9b3d-f4ee-4c75-964c-21de0855383f
# 20  04234952-cce8-41d6-8708-afd21fc6a73e
# 21  8b24838d-48af-49c3-a8d6-0b3bd8f1558a
# 22  2daa95e9-6e13-4eb9-99d3-d312d367c905
# 23  b0f8d019-9ad6-408e-9873-21e79b0608a2
# 24  16dcca3d-0ea4-4fe9-87b5-dbe1aa43271e
# 25  09cf4ca8-e9c4-4482-bda8-cb62ef9dd7a8
# 26  021b4036-04d5-46cf-9f3c-9e4bcef43c38
# 27  0909ad7a-d6bf-4692-92a2-40b214ad9bf6
# 28  b1374012-a85a-4201-8c2c-289b4786571f
# 29  b987a3a6-4375-42dd-8b80-d0dc3df725fc
# 30  02bf5660-0c91-4379-a07c-7841eca73072
# 31  fe53d829-d4fc-43f0-992e-d4eb1019b0c3
# 32  a728322c-b033-4d9d-b8fc-89baeb504118
# 33  3db69b52-8104-4d9f-b7fd-42d89a90641d
# 34  d8b937f7-02a8-479b-b30d-10b46f997ef4
# 35  59018294-c39d-4a59-8362-e714a4749c2c
# 36  4f98fe4b-e32d-44f7-907e-13adc3fce925
# 37  512857d4-4fc1-408d-960e-2979ead97535
# 38  8b139765-de80-4343-bf05-5c25c179a6a0
# 39  34faec33-aedc-47f9-a248-05b6dd1a59bd
#
#                                         text_unit_ids
# 0   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 1   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 2   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 3   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 4   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 5   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 6   [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 7   [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 8   [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 9   [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 10  [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 11  [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 12  [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 13  [ffb7364bae253823e37dd9c595945797e21df3bc98d21...
# 14  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 15  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 16  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 17  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 18  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 19  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 20  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 21  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 22  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 23  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 24  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 25  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 26  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 27  [88410825f07a88c4563e46ba096fba9b177e4e0a94186...
# 28  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 29  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 30  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 31  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 32  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 33  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 34  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 35  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 36  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 37  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 38  [529802d706f55a5645615079f368acfcbde1630f8f446...
# 39  [529802d706f55a5645615079f368acfcbde1630f8f446...

# %%
# 修改后的Cypher查询语句
entity_statement = """
MERGE (e:__Entity__ {id:value.id})
SET e += value {.human_readable_id, name:replace(value.title,'"',''), .description}
WITH e, value
// 过滤 description_embedding 中的无效值
WITH e, value, [x IN coalesce(value.description_embedding, [0.1]) WHERE x IS NOT NULL AND x <> 'NaN' AND x <> 'Infinity' AND x <> '-Infinity'] AS valid_description_embedding
CALL db.create.setNodeVectorProperty(e, "description_embedding", valid_description_embedding)
CALL apoc.create.addLabels(e, case when coalesce(value.type,"") = "" then [] else [apoc.text.upperCamelCase(replace(value.type,'"',''))] end) yield node
UNWIND value.text_unit_ids AS text_unit
MATCH (c:__Chunk__ {id:text_unit})
MERGE (c)-[:HAS_ENTITY]->(e)
"""

batched_import(entity_statement, entity_df)
# Out:
# {'_contains_updates': True, 'labels_added': 517, 'relationships_created': 552, 'nodes_created': 517, 'properties_set': 2068}
# 517 rows in 0.46076107025146484 s.
# 517

# %%
rel_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_relationships.parquet",
    columns=[
        "source",
        "target",
        "id",
        # "rank",
        "weight",
        "human_readable_id",
        "description",
        "text_unit_ids",
    ],
)
rel_df.head(2)
# Out:
#          source target                                    id  weight  \
# 0  CJ8WD89BJR24   我的亲家  d5c505a3-5865-4798-b141-841d0a3896f7    18.0
# 1          我的亲家   相亲平台  e76b87ca-9531-4ad7-ad87-644adf4d3a62    18.0
#
#    human_readable_id                       description  \
# 0                  0  广告主id为cj8wd89bjr24的广告主的产品是“我的亲家”
# 1                  1                       我的亲家是一个相亲平台
#
#                                        text_unit_ids
# 0  [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...
# 1  [759c5af2aad3e1985b6893b369a9b9781f045235d05d9...

# %%
rel_statement = """
    MATCH (source:__Entity__ {name:replace(value.source,'"','')})
    MATCH (target:__Entity__ {name:replace(value.target,'"','')})
    // not necessary to merge on id as there is only one relationship per pair
    MERGE (source)-[rel:RELATED {id: value.id}]->(target)
    SET rel += value {.rank, .weight, .human_readable_id, .description, .text_unit_ids}
    RETURN count(*) as createdRels
"""

batched_import(rel_statement, rel_df)
# Out:
# {'_contains_updates': True, 'relationships_created': 485, 'properties_set': 2425}
# 485 rows in 0.2628810405731201 s.
# 485

# %%
community_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_communities.parquet",
    columns=["id", "level", "title", "text_unit_ids", "relationship_ids"],
)

community_df.head(2)
# Out:
#                                      id  level        title  \
# 0  12d86941-2903-4bdf-a6b3-cde7e24c2157      0  Community 0
# 1  00e857f7-cdd8-4214-a0c1-549296baae9b      0  Community 1
#
#                                        text_unit_ids  \
# 0  [81b93d94bd0707aefca13a56a03f9453cf62b90875c45...
# 1  [8d7d308e2ecdade189510d84d64a81470466e382e01bc...
#
#                                     relationship_ids
# 0  [0822c360-037f-438f-b626-dd389314d650, 0860762...
# 1  [086ca1a8-29a2-40cd-a20e-86350bcb5072, 1387f8a...

# %%
statement = """
MERGE (c:__Community__ {community:value.id})
SET c += value {.level, .title}
/*
UNWIND value.text_unit_ids as text_unit_id
MATCH (t:__Chunk__ {id:text_unit_id})
MERGE (c)-[:HAS_CHUNK]->(t)
WITH distinct c, value
*/
WITH *
UNWIND value.relationship_ids as rel_id
MATCH (start:__Entity__)-[:RELATED {id:rel_id}]->(end:__Entity__)
MERGE (start)-[:IN_COMMUNITY]->(c)
MERGE (end)-[:IN_COMMUNITY]->(c)
RETURn count(distinct c) as createdCommunities
"""

batched_import(statement, community_df)
# Out:
# {'_contains_updates': True, 'labels_added': 43, 'relationships_created': 402, 'nodes_created': 43, 'properties_set': 129}
# 43 rows in 0.3289179801940918 s.
# 43

# %%
community_report_df = pd.read_parquet(
    f"{GRAPHRAG_FOLDER}/create_final_community_reports.parquet",
    columns=[
        "id",
        "community",
        "level",
        "title",
        "summary",
        "findings",
        "rank",
        "rank_explanation",
        "full_content",
    ],
)
community_report_df.head(2)
# Out:
#                                  id  community  level                  title  \
# 0  156f8f918d8347e0b2fefa3e5c3a89c8         14      1              牵手APP用户分析
# 1  2b1cdfded53d4f6eaa9c7b81adf062db         15      1  VNUW2BNVIPTRE广告主的合作偏好
#
#                                              summary  \
# 0  牵手APP作为一个生活服务-线上婚恋平台，主要针对25-29岁和18-24岁的粉丝群体，重点...
# 1  VNUW2BNVIPTRE广告主展现了多元化的达人类型合作期望，并倾向于采用二创剪辑及原创定...
#
#                                             findings  rank  \
# 0  [{'explanation': '牵手APP的主要目标人群为25-29岁和18-24岁的粉...   6.0
# 1  [{'explanation': 'VNUW2BNVIPTRE广告主期望合作的达人类型包括真...   6.0
#
#                                     rank_explanation  \
# 0  牵手APP作为一个针对特定年龄段和地区的线上婚恋平台，具有一定的用户基础和市场影响力。其用户...
# 1  VNUW2BNVIPTRE广告主的合作偏好广泛且具体，显示出其对不同达人类型和广告形式的多样...
#
#                                         full_content
# 0  # 牵手APP用户分析\n\n牵手APP作为一个生活服务-线上婚恋平台，主要针对25-29岁...
# 1  # VNUW2BNVIPTRE广告主的合作偏好\n\nVNUW2BNVIPTRE广告主展现了...

# %%
# Import communities
community_statement = """
MERGE (c:__Community__ {community:value.community})
SET c += value {.level, .title, .rank, .rank_explanation, .full_content, .summary}
WITH c, value
UNWIND range(0, size(value.findings)-1) AS finding_idx
WITH c, value, finding_idx, value.findings[finding_idx] as finding
MERGE (c)-[:HAS_FINDING]->(f:Finding {id:finding_idx})
SET f += finding
"""
batched_import(community_statement, community_report_df)
# Out:
# {'_contains_updates': True, 'labels_added': 220, 'relationships_created': 177, 'nodes_created': 220, 'properties_set': 832}
# 43 rows in 0.09284520149230957 s.
# 43

# %%
cov_df = (pd.read_parquet(f"{GRAPHRAG_FOLDER}/create_final_covariates.parquet"),)
#                         columns=["id","text_unit_id"])
cov_df.head(2)
# Subject id do not match entity ids
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cov_df = (pd.read_parquet(f"{GRAPHRAG_FOLDER}/create_final_covariates.parquet"),)
#       2 #                         columns=["id","text_unit_id"])
#       3 cov_df.head(2)
#
# File ~/Library/Caches/pypoetry/virtualenvs/graphrag-lV5KGJPV-py3.12/lib/python3.12/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/graphrag-lV5KGJPV-py3.12/lib/python3.12/site-packages/pandas/io/parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/graphrag-lV5KGJPV-py3.12/lib/python3.12/site-packages/pandas/io/parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File ~/Library/Caches/pypoetry/virtualenvs/graphrag-lV5KGJPV-py3.12/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/20250109-110754/artifacts/create_final_covariates.parquet'

# %%
# Import covariates
cov_statement = """
MERGE (c:__Covariate__ {id:value.id})
SET c += apoc.map.clean(value, ["text_unit_id", "document_ids", "n_tokens"], [NULL, ""])
WITH c, value
MATCH (ch:__Chunk__ {id: value.text_unit_id})
MERGE (ch)-[:HAS_COVARIATE]->(c)
"""
batched_import(cov_statement, cov_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       1 # Import covariates
#       2 cov_statement = """
#       3 MERGE (c:__Covariate__ {id:value.id})
#       4 SET c += apoc.map.clean(value, ["text_unit_id", "document_ids", "n_tokens"], [NULL, ""])
#    (...)
#       7 MERGE (ch)-[:HAS_COVARIATE]->(c)
#       8 """
# ----> 9 batched_import(cov_statement, cov_df)
#
# NameError: name 'cov_df' is not defined
